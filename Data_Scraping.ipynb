# %%
import os

# %%
# %load_ext pycodestyle_magic

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import unquote
import PyPDF2
from itertools import chain

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %pycodestyle_on

# %%
# Create text and pdf folders
os.chdir(os.getcwd())
if not os.path.exists("text"):
    os.makedirs("text")
if not os.path.exists("pdf"):
    os.makedirs("pdf")

# %%
# Source: https://github.com/maksimKorzh/one-time-scrapers/blob/master/scrapers/scrape_pdf/scrape.py

url = 'http://laserowatwierdza.pl/wyniki/'
lists = []
# make HTTP GET request to the target URL
print('HTTP GET: %s', url)
response = requests.get(url)

# parse content
content = BeautifulSoup(response.text, 'lxml')

# extract URLs referencing PDF documents
all_urls = content.find_all('a')

# loop over all URLs
for url in all_urls:
    # try URLs containing 'href' attribute
    try:
        # pick up only those URLs containing 'pdf'
        # within 'href' attribute
        if 'pdf' in url['href']:
            # init PDF url
            pdf_url = ''
            
            # append base URL if no 'https' available in URL
            if 'https' not in url['href']:
                pdf_url = 'https://dyysg.org.uk' + url['href']

            # otherwise use bare URL
            else:
                pdf_url = url['href']
            
            # make HTTP GET request to fetch PDF bytes
            print('HTTP GET: %s', pdf_url)          
            pdf_response = requests.get(pdf_url)
            # extract  PDF file name
            filename = unquote(pdf_response.url).split('/')[-1].replace(' ', '_')
            
            
            # write PDF to local file
            with open('./pdf/' + filename, 'wb') as f:
                lists.append(filename)
                # write PDF to local file
                #f = PyPDF2.PdfFileReader(f) 
                f.write(pdf_response.content)
                
    # skip all the other URLs
    except:
        pass
# Out:
# 1:80: E501 line too long (100 > 79 characters)
# 24:1: W293 blank line contains whitespace
# 32:1: W293 blank line contains whitespace
# 34:43: W291 trailing whitespace
# 37:80: E501 line too long (81 > 79 characters)
# 38:1: W293 blank line contains whitespace
# 39:1: W293 blank line contains whitespace
# 40:13: E303 too many blank lines (2)
# 44:17: E265 block comment should start with '# '
# 44:45: W291 trailing whitespace
# 46:1: W293 blank line contains whitespace
# 48:5: E722 do not use bare 'except'
# 50:1: W293 blank line contains whitespace
# 51:1: W391 blank line at end of file

# %%
#unpack second page of pdf to txt file
for i in range(0,len(lists)):
    pdfFileObj = open('./pdf/' + lists[i], 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    #print(pdfReader.numPages)
    pageObj = pdfReader.getPage(2)
    text = pageObj.extractText()
    with open('./text/' + lists[i] + '.txt', 'w') as f2:
        f2.write(text)
    pdfFileObj.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# 1:1: E265 block comment should start with '# '
# 2:17: E231 missing whitespace after ','
# 5:5: E265 block comment should start with '# '
# 10:23: W291 trailing whitespace

# %%
# extracting stats from second page
def stats_fun(page):
    stats = []
    pdfReader = PyPDF2.PdfFileReader(page)
    if pdfReader.numPages > 25:
        print("To big")
    else:
        pageObj = pdfReader.getPage(2)
        txt = pageObj.extractText()
        for i in range(1, int(len(txt.split("\n")[17:-1])/10) + 1):
            stats.append(txt.split("\n")[17:-1][-5 + 10*i :10*i])
    return stats
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\kacpe\appdata\local\programs\python\python39\lib\site-packages\pycodestyle_magic.py in auto_run_pycodestyle(self, result)
#      44
#      45     def auto_run_pycodestyle(self, result):
# ---> 46         pycodestyle(1, result.info.raw_cell, auto=True)
#      47         if result.error_before_exec:
#      48             print('Error before execution: %s' % result.error_before_exec)
#
# c:\users\kacpe\appdata\local\programs\python\python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\kacpe\appdata\local\programs\python\python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     218     # but it's overkill for just that one bit of state.
#     219     def magic_deco(arg):
# --> 220         call = lambda f, *a, **k: f(*a, **k)
#     221
#     222         # Find get_ipython() in the caller's namespace
#
# c:\users\kacpe\appdata\local\programs\python\python39\lib\site-packages\pycodestyle_magic.py in pycodestyle(line, cell, auto)
#     173         #logger.info(line)
#     174         # on windows drive path also contains :
# --> 175         line, col, error = line.split(':')[-4:]
#     176         # do not subtract 1 for line for %%pycodestyle, inc pre py3.6 string
#     177         if auto:
#
# ValueError: too many values to unpack (expected 3)

# %%
# extracting injuries for pages 3:
def injuries2(pdf):
    pdfReader = PyPDF2.PdfFileReader(pdf)
    # pageObj = pdfReader.getPage(3)
    stats = []
    if pdfReader.numPages > 25:
        print("To big")
    else:
        for k in range(3, pdfReader.numPages):
            pageObj = pdfReader.getPage(k)
            txt = pageObj.extract_text()
            stats.append(txt.split("get", 1)[1].split("\n")[1])
    return stats

# %%
# recall functions on all scrapped pdfs
stats = []
inj = []
for element in lists:
    pdfFileObj = open('./pdf/' + element, 'rb')
    stats2 = stats_fun(pdfFileObj)
    inj2 = injuries2(pdfFileObj)
    inj.append(inj2)
    stats = stats2 + stats  # list conection
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
len(lists)
# Out:
# 220

# %%
# reverse inj list
inj.reverse()

# %%
# reshape inj to 1 dim list
inj_flat = list(chain.from_iterable(inj))

# %%
# Checking

# %%
len(inj_flat)
# Out:
# 1850

# %%
len(stats)
# Out:
# 1850

# %%
# Same lenght it fine

# %%
inj_df = pd.DataFrame(inj_flat)

# %%
# Df with injuries
inj_df.columns = ["DMG_Get"]
inj_df
# Out:
#      DMG_Get
# 0        464
# 1        591
# 2        549
# 3        442
# 4        583
# ...      ...
# 1845      58
# 1846     186
# 1847     136
# 1848      53
# 1849     192
#
# [1850 rows x 1 columns]

# %%
# Df with other stats
df = pd.DataFrame(data=stats)
df.columns = ["Rating", "Accuracy", "Shot fired", "Hits", "Deaths"]

# %%
# Concating them
full_stats = pd.concat([df, inj_df], axis=1)
full_stats
# Out:
#      Rating Accuracy Shot fired Hits Deaths DMG_Get
# 0      70.8   20.10%       3509  704     40     464
# 1      55.8   15.80%       4771  753     54     591
# 2      47.6   16.70%       3526  589     59     549
# 3      47.5   15.20%       3184  484     42     442
# 4      24.7   10.30%       3481  359     66     583
# ...     ...      ...        ...  ...    ...     ...
# 1845   26.4    3.20%       1393   44      0      58
# 1846   21.1    6.40%       1643  105     11     186
# 1847   20.9    3.60%       2208   80      5     136
# 1848   19.9    1.90%       1630   31      2      53
# 1849   11.5    1.80%       3462   64     15     192
#
# [1850 rows x 6 columns]

# %%
# Save all important stats
full_stats.to_csv("Stats.csv", encoding="utf-8")
